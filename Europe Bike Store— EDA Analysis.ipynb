# %% [markdown]
# <h1 style="
#     text-align:center;
#     background-color:#004F98;
#     color:white;
#     padding:20px;
#     border-radius:10px;">
#     📊📉 Europe Bike Store  — Full EDA, KPI & Insights Report
# </h1>
# <p style="text-align:center;color:#1F4E79;font-size:1rem;margin-top:10px;">
# <b>Period:</b> Jan 2011 – Jul 2016 &nbsp;|&nbsp; <b>Records:</b> 113,036 &nbsp;|&nbsp; <b>Countries:</b> 6 &nbsp;|&nbsp; <b>Products:</b> 130 &nbsp;|&nbsp; <b>
# </p>

# %% [markdown]
# <h2 style="color:#2E86C1;">
#  1️⃣ 📚 Import Libraries
# </h2>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px

# %% [markdown]
# <h2 style="color:#2E86C1;">
# 2️⃣ 🎯📖 Reading Dataset
# </h2>

# %%
data=pd.read_csv("Sales.csv")
df=data.copy()
df.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %% [markdown]
# <h2 style="color:#2E86C1;">
# 3️⃣ 𝄜 Data Shap
# </h2>

# %%
print(f"  𝄜 Data Shape :{df.shape}" )
# Out:
#   𝄜 Data Shape :(113036, 18)

# %%
print(f'(☰)  Number of rows: {df.shape[0]}')
print(f'(|||) Number of columns: {df.shape[1]}')
# Out:
# (☰)  Number of rows: 113036
# (|||) Number of columns: 18

# %% [markdown]
# <h2 style="color:#2E86C1;">
# 4️⃣ 🔍Initial Data Exploration
# </h2>

# %%
print('📌 First 10 rows of the dataset:')
df.head(10)
# Out:
# 📌 First 10 rows of the dataset:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
# 5  2016-05-15   15       May  2016            47  Adults (35-64)
# 6  2014-05-22   22       May  2014            47  Adults (35-64)
# 7  2016-05-22   22       May  2016            47  Adults (35-64)
# 8  2014-02-22   22  February  2014            35  Adults (35-64)
# 9  2016-02-22   22  February  2016            35  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# ...

# %%
# Display last 5 rows
print('📌 Last 5 rows of the dataset:')
df.tail()
# Out:
# 📌 Last 5 rows of the dataset:
#               Date  Day  Month  Year  Customer_Age       Age_Group  \
# 113031  2016-04-12   12  April  2016            41  Adults (35-64)
# 113032  2014-04-02    2  April  2014            18     Youth (<25)
# 113033  2016-04-02    2  April  2016            18     Youth (<25)
# 113034  2014-03-04    4  March  2014            37  Adults (35-64)
# 113035  2016-03-04    4  March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country          State Product_Category  \
# 113031               M  United Kingdom        England         Clothing
# 113032               M       Australia     Queensland         Clothing
# 113033               M       Australia     Queensland         Clothing
# 113034               F          France  Seine (Paris)         Clothing
# 113035               F          France  Seine (Paris)         Clothing
#
#        Sub_Category          Product  Order_Quantity  Unit_Cost  Unit_Price  \
# ...

# %%
# General information about the dataset
print("\n" + "="*50 + "\n")
print('📋 Dataset Information:')
print(df.info())
print("\n" + "="*50 + "\n")
# Out:
# ...
#
# 📋 Dataset Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
# ...

# %%
# Column names
print("\n" + "="*100 + "\n")
print('📝 Column Names:')
print(df.columns.tolist())
print("\n" + "="*100 + "\n")
# Out:
# ...
#
# 📝 Column Names:
# ['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group', 'Customer_Gender', 'Country', 'State', 'Product_Category', 'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price', 'Profit', 'Cost', 'Revenue']
#
# ...

# %%
# Descriptive statistics for numerical columns

print('📊 Descriptive Statistics (Numerical):')
df.describe().T
# Out:
# 📊 Descriptive Statistics (Numerical):
#                    count         mean          std     min     25%     50%  \
# Day             113036.0    15.665753     8.781567     1.0     8.0    16.0
# Year            113036.0  2014.401739     1.272510  2011.0  2013.0  2014.0
# Customer_Age    113036.0    35.919212    11.021936    17.0    28.0    35.0
# Order_Quantity  113036.0    11.901660     9.561857     1.0     2.0    10.0
# Unit_Cost       113036.0   267.296366   549.835483     1.0     2.0     9.0
# Unit_Price      113036.0   452.938427   922.071219     2.0     5.0    24.0
# Profit          113036.0   285.051665   453.887443   -30.0    29.0   101.0
# Cost            113036.0   469.318695   884.866118     1.0    28.0   108.0
# Revenue         113036.0   754.370360  1309.094674     2.0    63.0   223.0
#
#                    75%      max
# Day               23.0     31.0
# Year            2016.0   2016.0
# Customer_Age      43.0     87.0
# Order_Quantity    20.0     32.0
# ...

# %%
# Descriptive statistics for categorical columns
print('📊 Descriptive Statistics (Categorical):')
df.describe(include='object') .T
# Out:
# 📊 Descriptive Statistics (Categorical):
#                    count unique                    top   freq
# Date              113036   1884             2016-03-01    288
# Month             113036     12                   June  11234
# Age_Group         113036      4         Adults (35-64)  55824
# Customer_Gender   113036      2                      M  58312
# Country           113036      6          United States  39206
# State             113036     53             California  22450
# Product_Category  113036      3            Accessories  70120
# Sub_Category      113036     17        Tires and Tubes  33870
# Product           113036    130  Water Bottle - 30 oz.  10794

# %% [markdown]
# <h2 style="color:#2E86C1;">
# 5️⃣🧹Data Cleaning & Preprocessing
# </h2>

# %% [markdown]
# 💡:The Date column is object so Converted the Date column into datetime format.
#
# Extracted time-based features: Month \Year\ Quarter.

# %%
df['Date']  = pd.to_datetime(df['Date'])
df['Year']         = df['Date'].dt.year
df['Month']        = df['Date'].dt.month
df['MonthName']    = df['Date'].dt.strftime('%b')
df['Quarter']       = df['Date'].dt.quarter.map({1:'Q1',2:'Q2',3:'Q3',4:'Q4'})
df['YearMonth']    = df['Date'].dt.to_period('M')
df['DayOfWeek']    = df['Date'].dt.day_name()
df.head()
# Out:
#         Date  Day  Month  Year  Customer_Age       Age_Group Customer_Gender  \
# 0 2013-11-26   26     11  2013            19     Youth (<25)               M
# 1 2015-11-26   26     11  2015            19     Youth (<25)               M
# 2 2014-03-23   23      3  2014            49  Adults (35-64)               M
# 3 2016-03-23   23      3  2016            49  Adults (35-64)               M
# 4 2014-05-15   15      5  2014            47  Adults (35-64)               F
#
#      Country             State Product_Category  ... Order_Quantity Unit_Cost  \
# 0     Canada  British Columbia      Accessories  ...              8        45
# 1     Canada  British Columbia      Accessories  ...              8        45
# 2  Australia   New South Wales      Accessories  ...             23        45
# 3  Australia   New South Wales      Accessories  ...             20        45
# 4  Australia   New South Wales      Accessories  ...              4        45
#
# ...

# %%
# Check for missing values
print('❌ Missing Values in Each Column:')
null_counts = df.isnull().sum()
print(null_counts)
# Out:
# ❌ Missing Values in Each Column:
# Date                0
# Day                 0
# Month               0
# Year                0
# Customer_Age        0
# Age_Group           0
# Customer_Gender     0
# Country             0
# State               0
# Product_Category    0
# Sub_Category        0
# Product             0
# Order_Quantity      0
# Unit_Cost           0
# Unit_Price          0
# Profit              0
# Cost                0
# Revenue             0
# MonthName           0
# Quarter             0
# YearMonth           0
# DayOfWeek           0
# dtype: int64

# %%
# Check for duplicate rows
duplicates_count = df.duplicated().sum()
print(f'🔍 Number of Duplicate Rows: {duplicates_count:}')
# Out:
# 🔍 Number of Duplicate Rows: 1000

# %%
df = df.drop_duplicates()

# %%
# Check for duplicate Columns
duplicates_count = df.T.duplicated().sum()
print(f'🔍 Number of Duplicate Columns: {duplicates_count:}')
# Out:
# 🔍 Number of Duplicate Columns: 0

# %%
df
# Out:
#              Date  Day  Month  Year  Customer_Age       Age_Group  \
# 0      2013-11-26   26     11  2013            19     Youth (<25)
# 1      2015-11-26   26     11  2015            19     Youth (<25)
# 2      2014-03-23   23      3  2014            49  Adults (35-64)
# 3      2016-03-23   23      3  2016            49  Adults (35-64)
# 4      2014-05-15   15      5  2014            47  Adults (35-64)
# ...           ...  ...    ...   ...           ...             ...
# 113031 2016-04-12   12      4  2016            41  Adults (35-64)
# 113032 2014-04-02    2      4  2014            18     Youth (<25)
# 113033 2016-04-02    2      4  2016            18     Youth (<25)
# 113034 2014-03-04    4      3  2014            37  Adults (35-64)
# 113035 2016-03-04    4      3  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# 0                    M          Canada  British Columbia      Accessories
# ...

# %%
#create new column that help at analysis (profit_margin)
df['Profit_Margin'] = (df['Profit'] / df['Revenue'] * 100).round(2)
df
# Out:
#              Date  Day  Month  Year  Customer_Age       Age_Group  \
# 0      2013-11-26   26     11  2013            19     Youth (<25)
# 1      2015-11-26   26     11  2015            19     Youth (<25)
# 2      2014-03-23   23      3  2014            49  Adults (35-64)
# 3      2016-03-23   23      3  2016            49  Adults (35-64)
# 4      2014-05-15   15      5  2014            47  Adults (35-64)
# ...           ...  ...    ...   ...           ...             ...
# 113031 2016-04-12   12      4  2016            41  Adults (35-64)
# 113032 2014-04-02    2      4  2014            18     Youth (<25)
# 113033 2016-04-02    2      4  2016            18     Youth (<25)
# 113034 2014-03-04    4      3  2014            37  Adults (35-64)
# 113035 2016-03-04    4      3  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# 0                    M          Canada  British Columbia      Accessories
# ...

# %%
print('='*60)
print('  DATASET OVERVIEW')
print('='*60)
print(f'  Date Range   : {df["Date"].min().date()}  →  {df["Date"].max().date()}')
print(f'  Countries    : {df["Country"].nunique()}  → {list(df["Country"].unique())}')
print(f'  Categories   : {df["Product_Category"].nunique()}  →{list(df["Product_Category"].unique())}')
print(f'  Products     : {df["Product"].nunique()}')
print(f'  Total Revenue: ${df["Revenue"].sum():,.0f}')
print(f'  Total Profit : ${df["Profit"].sum():,.0f}')
print(f'  Avg Margin   : {df["Profit_Margin"].mean():.1f}%')
print('='*60)
# Out:
# ...
#   DATASET OVERVIEW
# ...
#   Date Range   : 2011-01-01  →  2016-07-31
#   Countries    : 6  → ['Canada', 'Australia', 'United States', 'Germany', 'France', 'United Kingdom']
#   Categories   : 3  →['Accessories', 'Clothing', 'Bikes']
#   Products     : 130
#   Total Revenue: $84,826,772
#   Total Profit : $32,046,239
#   Avg Margin   : 47.2%
# ...

# %%
# Descriptive statistics for categorical columns
print('📊 Descriptive Statistics (Categorical):')
df.describe(include='object') .T
# Out:
# 📊 Descriptive Statistics (Categorical):
#                    count unique                    top   freq
# Age_Group         112036      4         Adults (35-64)  55358
# Customer_Gender   112036      2                      M  57813
# Country           112036      6          United States  38840
# State             112036     53             California  22220
# Product_Category  112036      3            Accessories  69312
# Sub_Category      112036     17        Tires and Tubes  33298
# Product           112036    130  Water Bottle - 30 oz.  10641
# MonthName         112036     12                    Jun  11127
# Quarter           112036      4                     Q2  32236
# DayOfWeek         112036      7               Saturday  16352

# %%
# Descriptive statistics for numerical columns

print('📊 Descriptive Statistics (Numerical):')
df.describe().T
# Out:
# 📊 Descriptive Statistics (Numerical):
#                    count                           mean                  min  \
# Date              112036  2014-11-23 05:22:32.008282880  2011-01-01 00:00:00
# Day             112036.0                      15.665607                  1.0
# Month           112036.0                        6.45339                  1.0
# Year            112036.0                    2014.400925               2011.0
# Customer_Age    112036.0                      35.919508                 17.0
# Order_Quantity  112036.0                      11.904254                  1.0
# Unit_Cost       112036.0                     267.819603                  1.0
# Unit_Price      112036.0                     453.850628                  2.0
# Profit          112036.0                     286.035194                -30.0
# Cost            112036.0                     471.103333                  1.0
# Revenue         112036.0                     757.138527                  2.0
# ...

# %%
num_cols = df.select_dtypes(include=np.number).columns
for col in num_cols:
    plt.figure(figsize=(6,3))
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()

# %%
plt.figure(figsize=(14,8))
sns.heatmap(df.corr(numeric_only=True),
            annot=True,
            cmap="coolwarm",
            fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# <h2 style="color:#2E86C1;">
# 6️⃣📈Analysis Data
# </h2>

# %% [markdown]
# <h2 style="color:#2E86C1;">
# 📊  Revenue KPI :
# </h2>

# %%
Total_Revenue=df['Revenue'].sum()
Total_Profit=df['Profit'].sum()
Avg_Profit_Margin=((df['Profit'].sum())/(df['Revenue'].sum()))*100
Total_Orders=df.shape[0]
Avg_Order_Value=Total_Revenue/Total_Orders
print(f"Total Revenue is ${Total_Revenue/1e6:.1f}M")    
print(f"Total Profit is ${Total_Profit/1e6:.1f}M")    
print(f"Avg Profit Margin is {Avg_Profit_Margin:.1f}%")
print(f"Total Orders is {Total_Orders:,}")    
print(f"Avg Order Value is ${Avg_Order_Value:.0f}")
# Out:
# Total Revenue is $84.8M
# Total Profit is $32.0M
# Avg Profit Margin is 37.8%
# Total Orders is 112,036
# Avg Order Value is $757

# %%
rev_year = df.groupby('Year')['Revenue'].sum()
ax = rev_year.plot(
    kind='bar',
    color='skyblue',
    edgecolor='black',
    figsize=(8,5)
)
plt.title("Total Revenue by Year", fontsize=14)
plt.xlabel("Year")
plt.ylabel("Revenue ($M)") 
plt.xticks(rotation=0)
ax.bar_label(
    ax.containers[0],
    labels=[f"${c/1e6:.1f}M" for c in rev_year],
    label_type='edge',
    padding=1
)
plt.tight_layout()
plt.show()

# %%
rev_year.plot(
    kind='line',
    marker='o',
    ms=7,
    linewidth=3,
    figsize=(12,6)
)
plt.title("Revenue Trend by Year", fontsize=16)
plt.xlabel("year")
plt.ylabel("Revenue ($M)")
plt.grid(alpha=0.5)
plt.show()

# %% [markdown]
# 💡 Insight :
#
# 1)Strong growth 2011→2013----->>>> Expansion into new markets or products
#
# 2)2014 decline ----->>> Seasonal competition or recession
#
# 3)Top 2015 ----->>> Successful marketing campaigns
#
# 4)2016 decline ----->> Data expires in July only!
#
# 5)Highest year: 2015 → $ 19.95M   &&   Lowest year :  2011  →  $8.95M

# %%
month_order = [ 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec' ]
rev_month = df.groupby('MonthName')['Revenue'].sum().reindex(month_order)
rev_month
# Out:
# MonthName
# Jan    6961166
# Feb    6805834
# Mar    7306140
# Apr    7568874
# May    8789287
# Jun    8978817
# Jul    5691960
# Aug    5692947
# Sep    5822197
# Oct    5956276
# Nov    6206951
# Dec    9046323
# Name: Revenue, dtype: int64

# %%
ax = rev_month.plot(
    kind='bar',
    color='steelblue',
    edgecolor='black',
    figsize=(10,6)
)
plt.title("Total Revenue by month", fontsize=14)
plt.xlabel("Month")
plt.ylabel("Revenue ($M)")
plt.xticks(rotation=45)
ax.bar_label(
    ax.containers[0],
    labels=[f"${c/1e6:.1f}M" for c in rev_month],
    padding=3
)
plt.tight_layout()
plt.show()

# %%
rev_month.plot(
    kind='line',
    marker='o',
    ms=7,
    linewidth=3,
    figsize=(12,6)
)
plt.title("Revenue Trend by Month", fontsize=16)
plt.xlabel("Month")
plt.ylabel("Revenue ($M)")
plt.xticks(range(len(month_order)), month_order, rotation=45)
plt.grid(alpha=0.5)
plt.show()

# %% [markdown]
# 💡 Insight :
#
# 1) 🏆 Top 3 Best-Selling Months
# December → $9.0M(Holiday Season 🎄)
#
# June → $9.0M (Summer 🌞)
#
# May → $8.8M (Spring 🌸)
#
# 2) 📉 Lowest 3 months sales
#
# 🔴 July → $5.7M
#
# 🔴 August → $5.7M
#
# 🔴 September → $5.8M (Late summer slump)
#
#
# 3) 📐 Difference between peak and trough
#
# December $9.0 M  vs July $5.7 M
#
# Difference = $3.3M → 58% higher!
#
# 📈 Rise: Jan → Jun (Peak Summer)
#
# 📉 Decline: Jun → Sep (Stagnation)
#
# 📈 Recovery: Sep → Dec (Holiday Season)

# %%
rev_quarter = df.groupby(['Year','Quarter'])['Revenue'].sum().reset_index()
pivot_rev = (rev_quarter.pivot(index='Year', columns='Quarter', values='Revenue').fillna(0))/ 1e6
pivot_rev
# Out:
# Quarter        Q1        Q2        Q3        Q4
# Year
# 2011     2.013453  2.088296  2.448010  2.402207
# 2012     2.039466  2.178960  2.486753  2.428616
# 2013     1.377221  1.587527  4.947958  7.204621
# 2014     6.018265  7.506162  0.515765  0.000000
# 2015     2.052850  2.408553  6.310194  9.174106
# 2016     7.571885  9.567480  0.498424  0.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap( pivot_rev,annot=True,fmt=".1f",cmap="Blues")
plt.title("Quarterly Revenue Heatmap($M)")
plt.show()

# %%
ax = pivot_rev.plot(
    kind='bar',
    figsize=(12,6),
    edgecolor='black',
    width=0.8,
    colormap='cividis' )
for container in ax.containers:
    ax.bar_label(container, fmt='$%.1f', fontsize=11)
plt.title("Quarterly Revenue by Year", fontsize=16, weight='bold')
plt.xlabel("Year")
plt.ylabel("Revenue ($M)")
plt.legend(title='Quarter',bbox_to_anchor=(1.0,1))
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# 💡 insights :
#
# 1)🏆 Strongest Quarter Ever
#
# Q4 2015 → $9.2M ⭐
#
# Q2 2016 → $9.6M (Incomplete Year)
#
# Q4 2013 → $7.2M
#
# 2) 📈 Clear Recurring Pattern
#
# 2013: Q1 Weak → Q4 Very Strong 📈
#
# 2015: Q1 Weak → Q4 Very Strong 📈
#
# ⭐ Pattern: Odd-numbered years grow towards the end of the year!
#
# Q1 → Weak (2011-2013) then exploded (2014, 2016) 🚀
#
# Q2 → Continuous growth, reaching $9.6M in 2016
#
# Q3 → Fluctuating: Strong in 2013 & 2015, weak in 2014 & 2016
#
# Q4 → Always the strongest in completed years 👑

# %%
Day_order = [ 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday','Thursday', 'Friday']
rev_day= df.groupby('DayOfWeek')['Revenue'].sum().reindex(Day_order)
ax = rev_day.plot(
    kind='bar',
    color='blue',
    edgecolor='black',
    figsize=(8,5)
)
plt.title("Total Revenue by Day", fontsize=14)
plt.xlabel("Days")
plt.ylabel("Revenue ($M)") 
plt.xticks(rotation=0)
ax.bar_label(
    ax.containers[0],
    labels=[f"${c/1e6:.1f}M" for c in rev_day],
    label_type='edge',
    padding=1
)
plt.tight_layout()
plt.show()

# %% [markdown]
# 💡 Insight :
#
# 1) 🏆 Top Days
#
#  Saturday → $12.5M ⭐ Highest
#
#  Sunday → $12.3M
#
#  Wednesday → $12.2M (Surprise!)
#
# 2)📉 Weakest Days
#
# 🔴 Thursday → $11.8M Lowest
#
# 🔴 Tuesday → $11.9M
#
# 3)💡 Weekly Pattern
#
# 📈 Rise: Saturday and Sunday (Weekend)
#
# 📉 Decline: Thursday and Tuesday
#
# 📊 Surprise: Wednesday is strong despite being midweek!

# %%
rev_Gender=df.groupby('Customer_Gender')["Revenue"].sum()
rev_Gender
# Out:
# Customer_Gender
# F    41694689
# M    43132083
# Name: Revenue, dtype: int64

# %%
rev_Gender.plot(kind='pie',autopct='%1.1f%%', figsize=(6,6), colors=['blue','green'],labels=['Female ($41,694,689)', 'Male ($43,132,083)'])
plt.title("Gender split Revenue Distribution", fontsize=14)
plt.ylabel("")
plt.show()

# %%
Margin_Gender=df.groupby('Customer_Gender')["Profit_Margin"].mean()
Margin_Gender
# Out:
# Customer_Gender
# F    47.115813
# M    47.303174
# Name: Profit_Margin, dtype: float64

# %%
Margin_Gender.plot(kind='pie',autopct='%1.1f%%', figsize=(6,6), colors=['Limegreen','Darkorange'],labels=['Female (47.11%)', 'Male (47.30%)'])
plt.title("Gender split Margin Profit Distribution", fontsize=14)
plt.ylabel("")
plt.show()

# %% [markdown]
# 💡 Insight :
#
# 2. 💰 Actual Revenue Difference
# 3.
# $43,132,083 - $41,694,689 = $1,437,394
#
# That is, males are only $1.4M higher out of a total of $84.8M
#
# ⚖️ The distribution is almost perfectly even
#
# ✅ No obvious gender bias
#
# ✅ The product is equally appealing to both genders.
#
# ✅ A diverse and healthy customer base.

# %% [markdown]
# <h2 style="color:#2E86C1;">
# 📊 Country KPI
# </h2>

# %%
country_kpi = df.groupby('Country').agg( Revenue=('Revenue','sum'),
    Profit=('Profit','sum'),
    Orders=('Revenue','count'),
    Margin=('Profit_Margin','mean')
).reset_index().sort_values('Revenue', ascending=False)
country_kpi
# Out:
#           Country   Revenue    Profit  Orders     Margin
# 5   United States  27777098  10997638   38840  48.154485
# 0       Australia  21196395   6740522   23736  41.839437
# 4  United Kingdom  10575628   4383987   13486  49.995621
# 3         Germany   8956724   3349991   11027  45.951524
# 2          France   8414745   2872082   10920  43.629670
# 1          Canada   7906182   3702019   14027  54.801000

# %%
ax = country_kpi.plot(
    kind='bar',
     x='Country',
    y='Revenue',
    color='orange',
    edgecolor='black',
    figsize=(10,6)
)

plt.title("  Total Revenue by Country", fontsize=14)
plt.xlabel("Country", fontsize=12)
plt.ylabel("Revenue ($M)", fontsize=12)
ax.bar_label( ax.containers[0],
              labels=[f"${c/1e6:.1f}M" for c in country_kpi["Revenue"]],
label_type='edge',
padding=3)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
profit_country=country_kpi.sort_values('Profit', ascending=False)
ax = profit_country.plot(
    kind='bar',
    x='Country',
    y='Profit',
    color='red',
    edgecolor='black',
    figsize=(10,6)
)
plt.title("  Total Profit by Country", fontsize=14)
plt.xlabel("Country", fontsize=12)
plt.ylabel("Revenue ($M)", fontsize=12)
ax.bar_label( ax.containers[0],
              labels=[f"${c/1e6:.1f}M" for c in profit_country["Profit"]],
label_type='edge',
padding=3)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
orders_country=country_kpi.sort_values('Orders', ascending=False)
ax =orders_country .plot(
    kind='bar',
    x='Country',
    y='Orders',
    color='mediumseagreen',
    edgecolor='black',
    figsize=(10,6)
)
plt.title("  Total Orders by Country", fontsize=14)
plt.xlabel("Country", fontsize=12)
plt.ylabel("Coint of Orders", fontsize=12)
ax.bar_label( ax.containers[0],
labels=[f"n={c:,.0f}" for c in orders_country["Orders"]],
label_type='edge',
padding=3)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
margin_country=country_kpi.sort_values('Margin', ascending=False)
ax = margin_country.plot(
    kind='bar',
    x='Country',
    y='Margin',
    color='skyblue',
    edgecolor='black',
    figsize=(10,6)
)
plt.title(" AVG Margin profit by Country", fontsize=14)
plt.xlabel("Country", fontsize=12)
plt.ylabel("AVG MARGIN (%)", fontsize=12)
ax.bar_label( ax.containers[0],
              labels=[f"{c:.1f}%" for c in margin_country["Margin"]],
label_type='edge',
padding=3)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# 💡 Insight :
#
# 1) 🏆 Largest Market — Revenue
#
#  United States → $27.8M (32.7% of total)
#
#  Australia → $21.2M (24.9% of total)
#
#
# Together = 57.6% of total revenue! 🎯
#
#
# 2) 💰 Highest Profit Margin — The Big Surprise!
#
#
#  Canada → 54.8% ⭐ Highest despite being the lowest!
#
# United Kingdom → 50.0%
#
# United States → 48.2%
#
# 🔴 Australia → 41.8%
#
#
# 3) 📦 Top Country for Orders
#
# United States → 38,840 orders (30.6%)
#
# Canada → 14,027 orders (despite lower revenue!)
#
#  Australia → 23,736 orders

# %%
top_states = df.groupby('State')['Revenue'].sum().nlargest(10)
top_states
# Out:
# State
# California          17529787
# England             10575628
# New South Wales      9125980
# British Columbia     7848334
# Washington           6701258
# Queensland           5055843
# Victoria             5038294
# Oregon               3435046
# Hessen               2067980
# Saarland             2026497
# Name: Revenue, dtype: int64

# %%
ax = top_states.plot(
    kind='bar',
    color='yellow',
    edgecolor='black',
    figsize=(10,6)
)
plt.title("Total Revenue by State", fontsize=14)
plt.xlabel("States")
plt.ylabel("Revenue ($M)")
plt.xticks(rotation=45)
ax.bar_label(
    ax.containers[0],
    labels=[f"${c/1e6:.1f}M" for c in top_states],
    padding=3
)
plt.tight_layout()
plt.show()

# %% [markdown]
# 💡 Insight :
#
# 1)California is the largest market by a considerable margin. >>> 17.5M Revenue
#
# 2)Australian States:New South Wales-Queensland-Victoria --->>Approximate Total Revenue:≈ 19M
#
# 3)Hesse and Saarland is lowest market

# %% [markdown]
# <h2 style="color:#2E86C1;">
# 📊 Product  KPI
# </h2>

# %%
category_kpi = df.groupby('Product_Category').agg(
    Revenue=('Revenue','sum'),
    Profit=('Profit','sum'),
    Orders=('Revenue','count'),
    Margin=('Profit_Margin','mean')
).reset_index().sort_values('Revenue', ascending=False)
category_kpi
# Out:
#   Product_Category   Revenue    Profit  Orders     Margin
# 1            Bikes  61434484  20399726   25794  32.592271
# 0      Accessories  15022766   8807194   69312  56.492085
# 2         Clothing   8369522   2839319   16930  31.496435

# %%
ax = category_kpi.plot(
     kind='bar',
    x='Product_Category',
    y='Revenue',
    color='lightseagreen',
    edgecolor='black',
    figsize=(10,6)
)
plt.title("Total Revenue by Product Category", fontsize=14)
plt.xlabel("Product Category")
plt.ylabel("Revenue ($M)")
plt.xticks(rotation=0)
ax.bar_label(
    ax.containers[0],
    labels=[f"${c/1e6:.1f}M" for c in category_kpi['Revenue']],
    padding=3
)
plt.tight_layout()
plt.show()

# %%
profit_category=category_kpi.sort_values('Profit', ascending=False)
ax = profit_category.plot(
     kind='bar',
    x='Product_Category',
    y='Profit',
    color='coral',
    edgecolor='black',
    figsize=(10,6)
)
plt.title("Total Profit by Product Category", fontsize=14)
plt.xlabel("Product Category")
plt.ylabel("profit ($M)")
plt.xticks(rotation=0)
ax.bar_label(
    ax.containers[0],
    labels=[f"${c/1e6:.1f}M" for c in profit_category['Profit']],
    padding=3
)
plt.tight_layout()
plt.show()

# %%
Order_category=category_kpi.sort_values('Orders', ascending=False)
ax = Order_category.plot(
     kind='bar',
    x='Product_Category',
    y='Orders',
    color='indianred',
    edgecolor='black',
    figsize=(10,6)
)
plt.title("Total Orders by Product Category", fontsize=14)
plt.xlabel("Product Category")
plt.ylabel("Count of Orders")
plt.xticks(rotation=0)
ax.bar_label(
    ax.containers[0],
    labels=[f"n={c:,.0f}" for c in Order_category['Orders']],
    padding=3
)
plt.tight_layout()
plt.show()

# %%
Margin_category=category_kpi.sort_values('Margin', ascending=False)
ax = Margin_category.plot(
     kind='bar',
    x='Product_Category',
    y='Margin',
    color='goldenrod',
    edgecolor='black',
    figsize=(10,6)
)
plt.title("AVG MARGIN OF Product Category", fontsize=14)
plt.xlabel("Product Category")
plt.ylabel("AVG MARGIN (%)")
plt.xticks(rotation=0)
ax.bar_label(
    ax.containers[0],
    labels=[f"{c:.1f}%" for c in Margin_category['Margin']],
    padding=3
)
plt.tight_layout()
plt.show()

# %% [markdown]
# 💡 Insight :
#
# 1)🏆 Largest Revenue Category
#
#  Bikes → $61.4M (72.4% of total) 👑
#
#  Accessories → $15.0M (17.7% of total)
#
#  Clothing → $8.4M (9.9% of total)
#
#
# 2) 💰 Margin — The Big Surprise!
#  Accessories → 45.5%  Highest margin
#
# Bikes       → 33.2%
#
#  Clothing    → 26.7%  lowest margin
#
# 3) 📦 Order distribution
#
# Accessories → 69,312  Highest orders
#
# Bikes       →   25,794
#
#  Clothing    → 16,930  lowest orders
#
# Accessories has many orders but in smaller values

# %%
sub_category = df.groupby('Sub_Category').agg(
    Revenue=('Revenue','sum'),
    Profit=('Profit','sum'),
    Orders=('Revenue','count')
).reset_index().sort_values('Revenue', ascending=False)
sub_category
# Out:
#          Sub_Category   Revenue    Profit  Orders
# 11         Road Bikes  33150708  10012631   13313
# 10     Mountain Bikes  21020794   8117801    8803
# 15      Touring Bikes   7262982   2269294    3678
# 7             Helmets   5738482   3378696   12150
# 14    Tires and Tubes   4598124   2685467   33298
# 9             Jerseys   4112382    603440    6006
# 12             Shorts   1740710   1034342    1794
# 2   Bottles and Cages   1390570    799882   15649
# 5             Fenders   1245733    748914    4032
# 8     Hydration Packs    990406    572668    1334
# 16              Vests    949063    518791     964
# 6              Gloves    871419    511654    2686
# 3                Caps    548777     77921    4358
# 0          Bike Racks    517800    304455     592
# 1         Bike Stands    342830    201221     455
# 4            Cleaners    198821    115891    1802
# 13              Socks    147171     93171    1122

# %%
rev_sub = sub_category.sort_values('Revenue', ascending=True)
ax = rev_sub.plot(
     kind='barh',
    x='Sub_Category',
     y='Revenue',
     color='slateblue',
    edgecolor='black',
    figsize=(14,8)
)
plt.title("Total Revenue by Sub Category", fontsize=16)
plt.ylabel("Sub Category" ,  fontsize=16)
plt.xlabel("Revenue ($M)",   fontsize=16)
plt.tick_params(axis='both', labelsize=14)
plt.xticks(rotation=0)
ax.bar_label(
    ax.containers[0],
    labels=[f"${c/1e6:.1f}M" for c in rev_sub['Revenue']],
    padding=1,
   fontsize=16
)
plt.tight_layout()
plt.show()

# %%
Profit_sub = sub_category.sort_values('Profit', ascending=True)
ax = Profit_sub.plot(
     kind='barh',
    x='Sub_Category',
     y='Profit',
     color='royalblue',
    edgecolor='black',
    figsize=(14,8)
)
plt.title("Total Profit by Sub Category", fontsize=16)
plt.ylabel("Sub Category" ,  fontsize=16)
plt.xlabel("Profit ($M)",   fontsize=16)
plt.xticks(rotation=0)
plt.tick_params(axis='both', labelsize=14)
ax.bar_label(
    ax.containers[0],
    labels=[f"${c/1e6:.1f}M" for c in Profit_sub['Profit']],
    padding=1,
   fontsize=16
)
plt.tight_layout()
plt.show()

# %%
Orders_sub = sub_category.sort_values('Orders', ascending=True)
ax = Orders_sub.plot(
     kind='barh',
    x='Sub_Category',
     y='Orders',
     color='skyblue',
    edgecolor='black',
    figsize=(14,8)
)
plt.title("Total Profit by Sub Category", fontsize=16)
plt.ylabel("Sub Category" ,  fontsize=16)
plt.xlabel("Profit ($M)",   fontsize=16)
plt.xticks(rotation=0)
plt.tick_params(axis='both', labelsize=14)
ax.bar_label(
    ax.containers[0],
    labels=[f"{c:,.0f}" for c in Orders_sub['Orders']],
    padding=1,
   fontsize=16
)
plt.tight_layout()
plt.show()

# %% [markdown]
# 💡 Insight :
#
# 1) 🏆 Bikes Dominate Revenue
#
# Road Bikes → $33.2M (39.1% of Total) 👑
#
# Mountain Bikes → $21.0M (24.7% of Total)
#
# Touring Bikes → $7.3M (8.6% of Total)
#
# 2) 📦 Most Ordered Sub-Category
#
# Tires & Tubes → 32,989 orders ← Frequently Asked Consumer Product!
#
# Bottles & Cages → 21,564 orders
#
# Mountain Bikes → 18,803 orders
#
# 3) Road Bikes → Huge revenue ✅ but only 30% margin ⚠️
#
#  Shorts → Small revenue but 59% margin ⭐
#
#  Jerseys → Medium revenue but only 14% margin 🔴
#
#  Tires & Tubes → High demand + 58% margin = Golden opportunity 🏆

# %%
cat_yr = df.groupby(['Year','Product_Category'])['Revenue'].sum().reset_index()
cat_yr
# Out:
#     Year Product_Category   Revenue
# 0   2011            Bikes   8951966
# 1   2012            Bikes   9133795
# 2   2013      Accessories   3361765
# 3   2013            Bikes   9758574
# 4   2013         Clothing   1996988
# 5   2014      Accessories   4267159
# 6   2014            Bikes   7525417
# 7   2014         Clothing   2247616
# 8   2015      Accessories   3265581
# 9   2015            Bikes  14742208
# 10  2015         Clothing   1937914
# 11  2016      Accessories   4128261
# 12  2016            Bikes  11322524
# 13  2016         Clothing   2187004

# %%
cat_yr['Revenue_M'] = cat_yr['Revenue'] / 1e6

plt.figure(figsize=(12, 6))

sns.lineplot(
    data=cat_yr,
    x='Year',
    y='Revenue_M',
    hue='Product_Category',
    marker='o',
    linewidth=2.5,
    markersize=9,
    palette='tab10'       
)
plt.title("Revenue Trend by Product Category over Year", fontsize=16)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Revenue ($)", fontsize=12)
plt.xticks(rotation=45)
plt.grid(alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# insights :
#
# 🚴 Bikes: Always the Main Engine
#
# 2011 → 100% of Revenue (Bikes Only!)
#
# 2012 → 100% of Revenue (Bikes Only!)
#
# 2013 → 64% of Revenue
#
# 2014 → 54% of Revenue ← Lowest Share
#
# 2015 → 74% of Revenue ← Strong Comeback
#
# 2016 → 64% of Revenue
#
# 2) Accessories & Clothing launched in 2013.
#
# 2011 & 2012 → Bikes only!
#
# 2013 → First appearance of Accessories & Clothing
#
# Possible reason: Expansion of the product line from 2013
#
# 3) 🏆 Best Year in Each Category
#
# Bikes → 2015 $14.7M ⭐
#
# Accessories → 2016 $4.1M ⭐
#
# Clothing → 2014 $2.2M ⭐

# %% [markdown]
# <h2 style="color:#2E86C1;">
# 📊 Customer Demographics KPI
# </h2>

# %%
age_rev = df.groupby('Age_Group')['Revenue'].sum().reset_index().sort_values('Revenue', ascending=False)
age_rev
# Out:
#               Age_Group   Revenue
# 0        Adults (35-64)  42367181
# 2  Young Adults (25-34)  30467032
# 3           Youth (<25)  11685489
# 1         Seniors (64+)    307070

# %%
ax = age_rev.head(10).plot(
    kind='bar',
     x='Age_Group',
    y='Revenue',
    color='dodgerblue',
    edgecolor='black',
    figsize=(10,6)
)

plt.title("  Revenue by Age Group", fontsize=14)
plt.xlabel("Age Group", fontsize=12)
plt.ylabel("Revenue ($)", fontsize=12)
ax.bar_label(
 ax.containers[0],
labels=[f"${c/1e6:.1f}M" for c in age_rev['Revenue']],
padding=2,
)
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
gcat = df.groupby(['Customer_Gender','Product_Category'])['Revenue'].sum().reset_index()
pivot_gcat = (gcat.pivot(index='Customer_Gender', columns='Product_Category', values='Revenue').fillna(0))/ 1e6
pivot_gcat
# Out:
# Product_Category  Accessories      Bikes  Clothing
# Customer_Gender
# F                    7.048561  30.786067  3.860061
# M                    7.974205  30.648417  4.509461

# %%
plt.figure(figsize=(10,6))
sns.heatmap( pivot_gcat,annot=True,fmt=".1f",cmap="YlOrRd",linewidths=2)
plt.title("Revenue ($M): Gender × Product Category")
plt.show()

# %%
age_country = df.groupby(['Country','Age_Group'])['Revenue'].sum().unstack().fillna(0)/1e6
ax = age_country.plot(
    kind='bar',
    figsize=(12,6),
    edgecolor='black',
    width=0.8,
    colormap='cividis' )
for container in ax.containers:
    ax.bar_label(container, fmt='$%.1f', fontsize=11)
plt.title("Revenue by Country & Age Group ($M)", fontsize=16, weight='bold')
plt.xlabel("Country")
plt.ylabel("Revenue ($M)")
plt.legend(title='Quarter',bbox_to_anchor=(0.5,1))
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
age_country
# Out:
# Age_Group       Adults (35-64)  Seniors (64+)  Young Adults (25-34)  \
# Country
# Australia             9.254685       0.055051              7.875357
# Canada                4.398632       0.040117              2.459409
# France                3.613545       0.013936              3.806335
# Germany               4.074657       0.028628              3.703920
# United Kingdom        5.169618       0.038566              3.821188
# United States        15.856044       0.130772              8.800823
#
# Age_Group       Youth (<25)
# Country
# Australia          4.011302
# Canada             1.008024
# France             0.980929
# Germany            1.149519
# United Kingdom     1.546256
# United States      2.989459

# %% [markdown]
# 💡 Insight :
#
# 1. 🏆 The Strongest Age Group Globally
#
# Adults (35-64) → $42.1M (49.6%) 👑
#
# Young Adults (25-34) → $30.4M (35.9%)
#
# Youth (<25) → $11.7M (13.8%)
#
# Seniors (64+) → $0.31M (0.4%) ← Very small!
#
# 2)🏆 Highest Revenue per age group
#
# Adults (35-64) → 🥇 US $15.9M
#
# Young Adults (25-34) → 🥇 US $8.8M
#
# Youth (<25) → 🥇 Australia $4.0M ← Not US!
#
# Seniors (64+) → 🥇 US $0.13M
#
# 3)Australia's youth products are more popular.

# %%
top_country  = df.groupby('Country')['Revenue'].sum().idxmax()
top_cat      = df.groupby('Product_Category')['Revenue'].sum().idxmax()
top_subcat   = df.groupby('Sub_Category')['Revenue'].sum().idxmax()
top_age      = df.groupby('Age_Group')['Revenue'].sum().idxmax()
best_margin  = df.groupby('Country')['Profit_Margin'].mean().idxmax()
peak_year    = df.groupby('Year')['Revenue'].sum().idxmax()
best_month   = df.groupby('Month', observed=True)['Revenue'].sum().idxmax()

insights = [
    ('🌍 Top Market',       f'{top_country} generates the most revenue overall.'),
    ('📦 Leading Category', f'{top_cat} is the top-performing category by revenue.'),
    ('🏆 Best Sub-Category',f'{top_subcat} leads all sub-categories in revenue.'),
    ('👥 Key Segment',      f'{top_age} is the highest revenue-generating age group.'),
    ('💰 Best Margin Mkt',  f'{best_margin} achieves the highest avg profit margin.'),
    ('📅 Peak Year',        f'{peak_year} was the strongest revenue year.'),
    ('📆 Best Month',       f'{best_month} consistently shows the highest sales volume.'),
    ('⚧️ Gender Parity',    'Revenue split between Male and Female customers is near equal.'),
]

print('='*65)
print('  KEY INSIGHTS & STRATEGIC TAKEAWAYS')
print('='*65)
for title, detail in insights:
    print(f'  {title}')
    print(f'     → {detail}')
    print()
print('RECOMMENDATIONS')
print('-'*65)
recs = [
    '1. Double down on Bikes — highest revenue AND strong margins.',
    '2. Invest in Adults (35-64) segment targeted campaigns.',
    f'3. Expand presence in {best_margin} — premium margin market.',
    '4. Capitalize on seasonal peaks with timely promotions.',
    '5. Explore cross-sell: pair Accessories with Bike purchases.',
    '6. Address low-margin sub-categories with pricing review.',
]
for r in recs:
    print(f'  {r}')
print('='*65)
# Out:
# ...
#   KEY INSIGHTS & STRATEGIC TAKEAWAYS
# ...
#   🌍 Top Market
#      → United States generates the most revenue overall.
#
#   📦 Leading Category
#      → Bikes is the top-performing category by revenue.
#
#   🏆 Best Sub-Category
#      → Road Bikes leads all sub-categories in revenue.
#
#   👥 Key Segment
#      → Adults (35-64) is the highest revenue-generating age group.
#
#   💰 Best Margin Mkt
#      → Canada achieves the highest avg profit margin.
#
#   📅 Peak Year
#      → 2015 was the strongest revenue year.
#
#   📆 Best Month
#      → 12 consistently shows the highest sales volume.
#
#   ⚧️ Gender Parity
#      → Revenue split between Male and Female customers is near equal.
#
# RECOMMENDATIONS
# -----------------------------------------------------------------
#   1. Double down on Bikes — highest revenue AND strong margins.
#   2. Invest in Adults (35-64) segment targeted campaigns.
#   3. Expand presence in Canada — premium margin market.
# ...
